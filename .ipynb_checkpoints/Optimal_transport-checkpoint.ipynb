# %% [markdown]
# # Optimal Transport

# %% [markdown]
# ## Importations and tools functions

# %% [markdown]
# ### Importations

# %%
# %pip install sympy
# %pip install POT
# %pip install boto3
# %pip install --upgrade git+https://github.com/WandrilleBuchy/dopython/blob/main/dopython
# %pip install dcor

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sc
import seaborn as sns
import numpy as np
import ot
import ot.plot
import sklearn.metrics as sme
import matplotlib.pylab as pl
import os
import math
import dcor
import dopython
import importlib

from collections import defaultdict
from types import SimpleNamespace
from scipy.stats import vonmises,ecdf
from scipy.optimize import minimize_scalar
from warnings import warn
from sympy import Interval, Union
from itertools import combinations
from joblib import Parallel, delayed
from sklearn.cluster import HDBSCAN
from statsmodels.stats.multitest import multipletests

importlib.reload(dopython)

# %%
import sys
sys.path.append('/home/onyxia/work/torus_test_traduction/')

import stat_s1_python
import sim_null_stat_python
import twosample_test_s1_python

# %%
NR = 500

try:
    sim_free_null   
except NameError:
    sim_free_null = sim_null_stat_python.sim_null_stat(NR, NC=2)

# %%
bases_list = ["AAA", "AAC", "CAC", "CAA", "CCC", "CCA", "ACC", "ACA"]
angles_list = ['alpha', 'beta', 'gamma', 'delta', 'epsilon', 'zeta']
full_angles_list = ['alpha', 'beta', 'gamma', 'delta', 'epsilon', 'zeta', 'chi', 'nu0', 'nu1', 'nu2', 'nu3', 'nu4']
conformations = ["C3' endo", "C4' exo", "O4' endo", "C1' exo", "C2' endo", "C3' exo", "C4' endo", "O4' exo", "C1' endo", "C2' exo"]

data_path = "/home/onyxia/work/Data/"
torus_trad_path = "/home/onyxia/work/torus_test_traduction/"

# %%
dfs = {}

for base in bases_list:
    dfs[base] = pd.read_csv(f"{data_path}angles_RNA_{base}.csv")

df_all_angles = pd.concat(dfs, axis=1)

# %%
mid_angles = {}
first_angles = {}
last_angles = {}

cols_to_drop = ["res_id", "res_name"]

for base in bases_list:
    
    mid_angles[base] = dfs[base][dfs[base]["res_id"].isin([2])].drop(columns=cols_to_drop)
    first_angles[base] = dfs[base][dfs[base]["res_id"].isin([1])].drop(columns=cols_to_drop)
    last_angles[base] = dfs[base][dfs[base]["res_id"].isin([3])].drop(columns=cols_to_drop)

mid_angles["AAA"]

# %%
mid_6angles = {}
first_6angles = {}
last_6angles = {}
mid_nu = {}
first_nu = {}
last_nu = {}

for base in bases_list:

    mid_6angles[base] = mid_angles[base][["alpha", "beta", "gamma", "delta", "epsilon", "zeta"]]
    first_6angles[base] = first_angles[base][["alpha", "beta", "gamma", "delta", "epsilon", "zeta"]]
    last_6angles[base] = last_angles[base][["alpha", "beta", "gamma", "delta", "epsilon", "zeta"]]
    
    mid_nu[base] = mid_angles[base][["nu0", "nu1", "nu2", "nu3", "nu4"]]
    first_nu[base] = first_angles[base][["nu0", "nu1", "nu2", "nu3", "nu4"]]
    last_nu[base] = last_angles[base][["nu0", "nu1", "nu2", "nu3", "nu4"]]

# %% [markdown]
# ### Tool functions

# %%
def s3_upload(uploaded_path, uploaded_name, upload_path = "DihedralAnglesStudy/DistanceMatrices/"):

    import boto3, os

    s3 = boto3.client("s3",
                      endpoint_url="https://minio-simple.lab.groupe-genes.fr",
                      aws_access_key_id=os.environ["AWS_ACCESS_KEY_ID"],
                      aws_secret_access_key=os.environ["AWS_SECRET_ACCESS_KEY"],
                      aws_session_token=os.environ["AWS_SESSION_TOKEN"])

    fichier = uploaded_path
    s3.upload_file(fichier, "wbuchy-ensai", f"{upload_path}{uploaded_name}")
    print("Upload done !")

# %%
def tore_dist(x, y):
    
    x, y = np.atleast_1d(x), np.atleast_1d(y)
    angle_value = 360.0
    half_val = 180.0
    
    dist_sq = 0.0
    for i in range(len(x)):
        diff = x[i] - y[i]
        short_diff = (diff + half_val) % angle_value - half_val
        dist_sq += short_diff**2
        
    return np.sqrt(dist_sq)

# %%
def tore_dist_centred(x, y):
    x, y = np.atleast_1d(x), np.atleast_1d(y)
    diff = x - y
    short_diff = (diff + 0.5) % 1.0 - 0.5
    return np.sqrt(np.sum(short_diff ** 2))

# %%
def tore_dist_p(x, y, p, centred = False):
    if(centred == False):
        return(tore_dist(x,y)**p)
    elif(centred == True):
        return(tore_dist_centred(x,y)**p)
    else:
        raise ValueError("Boolean needed for centred")

# %%
def quadra_cost(x,y):
    return((x - y)**2)

# %%
def eIntegrate(fun, a = 0, b = 1, n = 1000):
    stairs = np.arange(a, b, 1/n)
    stairs = np.append(stairs, b)
    sum_darboux_plus, sum_darboux_minus = 0, 0
    
    for i in range(len(stairs)-1):
        sum_darboux_plus += (stairs[i+1] - stairs[i]) * max(fun(stairs[i+1]), fun(stairs[i]))
        sum_darboux_minus += (stairs[i+1] - stairs[i]) * min(fun(stairs[i+1]), fun(stairs[i]))

    return(np.mean(sum_darboux_plus, sum_darboux_minus))

# %%
def P_fun(thetas, tau_out = False):

    A = B = 0
    
    for i in range(5):
        alpha_deg = 144 * i
        alpha_rad = math.radians(alpha_deg)
        A += thetas.iloc[i] * math.cos(alpha_rad)
        B += thetas.iloc[i] * math.sin(alpha_rad)

    A = (2/5) * A
    B = (-2/5) * B

    tau_m = math.sqrt(A**2 + B**2)
    P_rad = math.atan2(B, A)

    P_deg = math.degrees(P_rad)
    
    if P_deg < 0:
        P_deg += 360
    
    if tau_out:
        return(P_deg, tau_m)
        
    return(P_deg)

# %%
def get_pucker_conf(P_theta):
    index = int(np.floor(P_theta/36))
    
    return(conformations[index])

# %% [markdown]
# ## Distance calculation

# %% [markdown]
# ### Distance functions

# %%
def bins_generator(mean_val, bins):
    
    if (bins > 180): 
        raise ValueError("Bins cannot be bigger than 180°")

    diffMbins = mean_val - bins
    sumMbins = mean_val + bins
    
    if (diffMbins < 0):
        int1 = Interval(0, mean_val)
        int2 = Interval(diffMbins % 360, 360)
        bound_inf = Union(int1, int2)
        bound_sup = Interval(mean_val, sumMbins)
        return(Union(bound_inf, bound_sup))
        
    elif (sumMbins > 360):
        int1 = Interval(0, sumMbins % 360)
        int2 = Interval(mean_val, 360)
        bound_sup = Union(int1, int2)
        bound_inf = Interval(diffMbins, mean_val)
        return(Union(bound_inf, bound_sup))
        
    else :
        return(Interval(diffMbins,sumMbins))

# %%
bins_generator(355,15)

# %%
in_bins = np.vectorize(lambda x: x in bins_generator(305,5))

# %%
xs = mid_6angles['AAA'][in_bins(mid_6angles['AAA']["beta"])][["alpha"]].to_numpy()
xt = mid_6angles["AAA"][["alpha"]].to_numpy()

# %%
cost_matrix = ot.dist(xs, xt, metric = lambda x, y: tore_dist_p(x, y, 2))

# %%
a, b = np.ones(len(xs))/len(xs), np.ones(len(xt))/len(xt)

# %%
test = ot.solve(cost_matrix, a, b)

# %%
test.plan

# %%
np.sqrt(test.value)

# %%
# xs = mid_6angles['AAA'][["alpha"]].to_numpy()
# xt = mid_6angles["AAA"][["beta"]].to_numpy()
# cost_matrix = ot.dist(xs, xt, metric = lambda x, y: tore_dist_p(x, y, 2))
# a, b = np.ones(len(xs))/len(xs), np.ones(len(xt))/len(xt)
# test = ot.solve(cost_matrix, a, b)
# print(test.plan)
# np.sqrt(test.value)

# %%
dist_max = np.sqrt(2)*180

# %%
def w_dist(xs, xt, joined_data_1 = False, joined_data_2 = False, mean_val_1 = 180, mean_val_2 = 180, bins_side_size_1 = 5, bins_side_size_2 = 5, p = 2, a = 'uniform', b = 'uniform'):
    
    in_bins_1 = np.vectorize(lambda x: x in bins_generator(mean_val_1, bins_side_size_1))
    in_bins_2 = np.vectorize(lambda x: x in bins_generator(mean_val_2, bins_side_size_2))

    xs_masked, xt_masked = xs[in_bins_1(xs)].to_numpy(), xt[in_bins_2(xt)].to_numpy()


    if not isinstance(joined_data_1, bool):
        mask1 = in_bins_1(joined_data_1)
        if mask1.sum() == 0:
            raise ValueError("No points in the bins of the first dimension")
        xs_masked = xs[mask1].to_numpy()
        
    if not isinstance(joined_data_2, bool):
        mask2 = in_bins_2(joined_data_2)
        if mask2.sum() == 0:
            raise ValueError("No points in the bins of the second dimension")
        xt_masked = xt[mask2].to_numpy()
    
    if len(xs_masked) == 0 or len(xt_masked) == 0:
        raise ValueError("No points in the bins")

    if (a == 'uniform'):
        a = np.ones(len(xs_masked))/len(xs_masked)

    if (b == 'uniform'):
        b = np.ones(len(xt_masked))/len(xt_masked)

        
    solved = ot.solve_sample(X_a = xs_masked, X_b = xt_masked, a = a, b = b, metric = lambda x, y: tore_dist_p(x, y, p))

    pvalue = twosample_test_s1_python.twosample_test_s1(xs_masked.flatten()/360, xt_masked.flatten()/360, sim_free_null).pvalue


    return SimpleNamespace(plan = solved.plan, value = solved.value**(1/p), pvalue = pvalue)

# %%
#testing_fun = w_dist(xs = mid_6angles["AAA"][["alpha"]], xt = mid_6angles["AAA"][["alpha"]], joined_data_1 = mid_6angles['AAA']["zeta"], mean_val_1 = 305, bins_side_size_2 = 179)

# %%
def optimized_w_dist(xs, xt, p = 2, n = 1000):

    xs, xt = xs.to_numpy().flatten(), xt.to_numpy().flatten()
    centred_xs, centred_xt = xs/360, xt/360

    Fxs = ecdf(centred_xs)
    Fxt = ecdf(centred_xt)

    def inv_Fxs(s):
        bounds = (0, s)
        return(minimize_scalar(Fxs.cdf.evaluate, bounds = bounds, method = "Bounded"))

    def inv_Fxt(s):
        bounds = (0, s)
        return(minimize_scalar(Fxt.cdf.evaluate, bounds = bounds, method = "Bounded"))

    def darboux_integral(alpha):
        def optimized(u):
            return tore_dist_p(inv_Fxs(u).x, inv_Fxt((u - alpha) % 1).x, p=p)

        stairs = np.linspace(0, 1, n + 1)
        sum_plus, sum_minus = 0, 0

        for i in range(len(stairs) - 1):
            h = stairs[i + 1] - stairs[i]
            vals = optimized(stairs[i + 1]), optimized(stairs[i])
            sum_plus  += h * max(vals)
            sum_minus += h * min(vals)

        return np.mean([sum_minus, sum_plus])

    result = minimize_scalar(darboux_integral, bounds=(0, 1), method="Bounded")

    return SimpleNamespace(x_value = result.x, value = result.fun)

# %%
#optimized_w_dist(mid_6angles["AAA"][["alpha"]], mid_6angles["AAA"][["beta"]]).value

# %%
def w_dist_conditional_y(X, Y, y_center, bins_side_size = 5, p = 2, n_min = 30):

    interval = bins_generator(y_center, bins_side_size)
    mask = np.array([y in interval for y in Y])

    X_conditional = X[mask].to_numpy().reshape(-1, 1)
    X_full = X.to_numpy().reshape(-1, 1)

    if len(X_conditional) < n_min :
        return SimpleNamespace(value=np.nan, pvalue=np.nan, plan=None, statistic = np.nan)

    a = np.ones(len(X_conditional)) / len(X_conditional)
    b = np.ones(len(X_full)) / len(X_full)

    solved = ot.solve_sample(
        X_a=X_conditional,
        X_b=X_full,
        a=a, b=b,
        metric=lambda x, y: tore_dist_p(x, y, p)
    )

    testing = twosample_test_s1_python.twosample_test_s1(X_full.flatten()/360, X_conditional.flatten()/360, sim_free_null)

    return SimpleNamespace(plan = solved.plan, value = solved.value**(1/p), pvalue = testing.pvalue, statistic = testing.stat)

# %% [markdown]
# ### Experimentations for the $\mathbb{S}^1$ tests

# %%
stock_exp = {}
for i in range(1000):
    x, y = np.random.rand(100), np.random.rand(100)
    stock_exp[i] = twosample_test_s1_python.twosample_test_s1(x, y, sim_free_null).pvalue

stock_exp = np.array(list(stock_exp.values()))

# %%
plt.hist(stock_exp, edgecolor = 'black')
plt.title(r"pvalues of the 1000 two 100-samples tests on $\mathbb{S}^1$")

# %%
plt.ecdf(stock_exp)
time = np.arange(0,1,.001)
plt.plot(time,time, linestyle = '--', alpha = .7, color = 'red')
plt.legend(['p-values eCDF', 'x = y'])
plt.title(r"p-values eCDF of the 1000 two 100-samples tests on $\mathbb{S}^1$")

# %% [markdown]
# ### Tests on the real data

# %%
def w_dist_conditional_y_graph_uni(X_angle_name, base, bins_side_size=5, p=2):

    X = mid_6angles[base][X_angle_name]
    y_centers = np.arange(0, 360, bins_side_size)

    fig, ax = plt.subplots(figsize=(10, 6))
    for angle_name in [k for k in mid_6angles[base].keys() if k != X_angle_name]:
        Y = mid_6angles[base][angle_name]
        distances = Parallel(n_jobs=-1)(
            delayed(w_dist_conditional_y)(X, Y, y, bins_side_size, p=p) 
            for y in y_centers
        )
        ax.plot(y_centers, [d.value for d in distances], label=angle_name)

    ax.set_xlabel("Y (dihedral angle)")
    ax.set_ylabel(f"W( P({X_angle_name}|Y=y), P({X_angle_name}) )")
    ax.set_title(f"Conditionnal Wasserstein - {base}")
    ax.legend()

    plt.tight_layout()
    plt.show()

# %%
#w_dist_conditional_y_graph_uni('alpha','AAA')

# %%
def w_dist_conditional_y_graph(X_angle_name, bins_side_size=5, p=2):
    y_centers = np.arange(0, 360, bins_side_size)
    fig, axes = plt.subplots(2, 4, figsize=(24, 15))
    axes = axes.flatten()

    for i, base in enumerate(bases_list):
        X = mid_6angles[base][X_angle_name]        
        for angle_name in [k for k in mid_6angles[base].keys() if k != X_angle_name]:
            Y = mid_6angles[base][angle_name]

            distances = Parallel(n_jobs=-1)(
                delayed(w_dist_conditional_y)(X, Y, y, bins_side_size, p=p)
                for y in y_centers
            )
            axes[i].plot(y_centers, [d.value for d in distances], label=angle_name)
            
        axes[i].set_xlabel("Y (dihedral angles)")
        axes[i].set_ylabel(f"W( P({X_angle_name}|Y=y), P({X_angle_name}) )")
        axes[i].set_title(f"Conditionnal Wasserstein - {base}")
        axes[i].legend()    

    plt.suptitle(f'Wasserstein distance for the angle {X_angle_name}')
    plt.tight_layout()
    plt.show()

# %%
#w_dist_conditional_y_graph('alpha')

# %%
# def calc_and_save(base, X_angle, Y_angle):
#     save_path = f'wasserstein_results/{base}_{X_angle}_{Y_angle}_distance.npy'
    
#     if os.path.exists(save_path):
#         print(f"  [SKIP] {base} | {X_angle} vs {Y_angle} déjà calculé")
#         return
    
#     print(f"  [START] {base} | {X_angle} vs {Y_angle}")
    
#     X = mid_angles[base][X_angle]
#     Y = mid_angles[base][Y_angle]
    
#     results = [w_dist_conditional_y(X, Y, y, bins_side_size=5) for y in y_centers]
    
#     data = np.array([
#         [r.value, r.pvalue, r.statistic] for r in results
#     ])  # shape (72, 3)
    
#     np.save(save_path, data)
#     print(f"  [DONE] {base} | {X_angle} vs {Y_angle} -> {save_path}")

def load_results(base, X_angle):
    other_angles = [a for a in full_angles_list if a != X_angle]
    dfs = {}
    
    for Y_angle in other_angles:
        path = f'/home/onyxia/work//DihedralAnglesStudy/wasserstein_results/{base}_{X_angle}_{Y_angle}_distance.npy'
        data = np.load(path)
        dfs[Y_angle] = pd.DataFrame(
            data,
            index=y_centers,
            columns=[f'distance_{Y_angle}', f'pvalue_{Y_angle}', f'statistic_{Y_angle}']
        )
    
    return pd.concat(dfs.values(), axis=1)

# %%
# os.makedirs('wasserstein_results', exist_ok=True)
# y_centers = np.arange(0, 360, 5)

# combos = [
#     (base, X_angle, Y_angle)
#     for base in bases_list
#     for X_angle in full_angles_list
#     for Y_angle in [a for a in full_angles_list if a != X_angle]
# ]

# print(f"Total : {len(combos)} combinaisons ({len(combos) * 72} appels OT)")

# Parallel(n_jobs=-1, backend='threading')(
#     delayed(calc_and_save)(base, X_angle, Y_angle)
#     for base, X_angle, Y_angle in combos
# )

# print("Terminé.")

# %%
# wasserstein = {}

# for X_angle in full_angles_list:
#     wasserstein[X_angle] = {}
#     for base in bases_list:
#         wasserstein[X_angle][base] = load_results(base, X_angle)

# for X_angle in full_angles_list:
#     pvalues_cols = [f"pvalue_{Y_angle}" for Y_angle in full_angles_list if Y_angle != X_angle]
#     adjusted_pvalues_cols = [f"adjusted_pvalue_{Y_angle}" for Y_angle in full_angles_list if Y_angle != X_angle]
#     for base in bases_list:
#         df = wasserstein[X_angle][base][pvalues_cols]

#         original_shape = df.shape
#         original_index = df.index
#         original_columns = df.columns

#         pvals_flat = df.to_numpy().flatten()
#         corrected = multipletests(pvals=pvals_flat, method='bonferroni')[1]

#         corrected_df = pd.DataFrame(corrected.reshape(original_shape),
#                                     index=original_index,
#                                     columns=original_columns)

#         wasserstein[X_angle][base][adjusted_pvalues_cols] = corrected_df
            
# np.save('/home/onyxia/work/Data/full_Wasserstein_distances', wasserstein)

wasserstein = np.load('/home/onyxia/work/Distance Matrices/full_Wasserstein_distances.npy', allow_pickle=True).item()

# %%
keeped_H0 = defaultdict(lambda: defaultdict(lambda: defaultdict(lambda: defaultdict(int))))

for X_angle in full_angles_list:
    for base in bases_list:
        for Y_angle in full_angles_list:
            if Y_angle == X_angle:
                continue
            for bins in range(0, 360, 5):
                adjusted_pval = wasserstein[X_angle][base][f"adjusted_pvalue_{Y_angle}"][bins]
                keeped_H0[X_angle][base][f"statistic_{Y_angle}"][bins] = 1 if adjusted_pval > .05 else 0

# %%
def rep_wass_mono_angle(X_angle, representation="distance", alpha=False, change_type_line=False):

    representation_list = ["distance", "pvalue", "statistic", "adjusted_pvalue"]
    if X_angle not in full_angles_list:
        raise ValueError(f"X_angle has to be in {full_angles_list}")
    if representation not in representation_list:
        raise ValueError(f"representation has to be in {representation_list}")   

    fig, axes = plt.subplots(2, 4, figsize=(20, 13))
    axes = axes.flatten()

    for i, base in enumerate(bases_list):
        for Y_angle in [a for a in full_angles_list if a != X_angle]:
            y_values = wasserstein[X_angle][base][f"{representation}_{Y_angle}"]            

            if representation == "statistic" and X_angle in keeped_H0 and base in keeped_H0[X_angle] and f"statistic_{Y_angle}" in keeped_H0[X_angle][base]:

                h0_values = keeped_H0[X_angle][base][f"statistic_{Y_angle}"]
                x_values = y_values.index

                segments = []
                current_style = None
                seg_x, seg_y = [], []

                for x, y in zip(x_values, y_values):
                    h0 = h0_values.get(x, 0)
                    style = ["-", 1] if h0 == 0 else ["--", 0.6]

                    if current_style is None or style[0] != current_style[0]:
                        if seg_x:
                            segments.append((seg_x, seg_y, current_style[0], current_style[1]))
                        seg_x, seg_y = [x], [y]
                        current_style = style

                    else:
                        seg_x.append(x)
                        seg_y.append(y)
                        
                if seg_x:
                    segments.append((seg_x, seg_y, current_style[0], current_style[1]))

                color = None
                for j, (sx, sy, st, sa) in enumerate(segments):

                    if j == 0:
                        ghost, = axes[i].plot([], [], linestyle="-", color=color if color else "C0", label=f"{Y_angle}")
                        line, = axes[i].plot(sx, sy, linestyle=st, alpha=sa)
                        color = line.get_color()
                        ghost.set_color(color)
                    else:
                        axes[i].plot(sx, sy, linestyle=st, alpha=sa, color=color)

            else:
                axes[i].plot(y_values, label=f"{Y_angle}")

        if isinstance(alpha, (int, float)) and not isinstance(alpha, bool):
            axes[i].axhline(alpha, color="black", linestyle="--",
                            label=f"{round(alpha, 3)} threshold")

        axes[i].set_xlabel("Y (dihedral angles)")
        axes[i].set_ylabel(f"{representation}")
        axes[i].set_title(f"Conditionnal Wasserstein - {base}")
        handles, labels = axes[i].get_legend_handles_labels()

        filtered = [(h, l) for h, l in zip(handles, labels) if h.get_linestyle() == "-"]
        if filtered:
            handles_f, labels_f = zip(*filtered)
            axes[i].legend(handles_f, labels_f)
        else:
            axes[i].legend()   

    plt.suptitle(f'{representation}s for the angle {X_angle}')
    plt.tight_layout()
    plt.show()

# %%
rep_wass_mono_angle(X_angle = "alpha", representation = "statistic", change_type_line = True)

# %%
rep_wass_mono_angle(X_angle = "alpha", representation = "adjusted_pvalue", alpha = 0.05)

# %%
def global_pvals(angles, base):
    X_angle, Y_angle = angles

    Y = mid_angles[base][Y_angle]
    obj = wasserstein[X_angle][base][f"statistic_{Y_angle}"]

    bin_counts = pd.Series({
        b: ((Y >= b) & (Y < b + 5)).sum()
        for b in obj.index
    })
    
    mean_stat = (obj*bin_counts).sum()/len(Y)
    out_val = np.mean(sim_free_null >= mean_stat)

    return SimpleNamespace(pval = out_val, stat = mean_stat)

# %%
global_pvals_stock = {}
global_stats_stock = {}
for base in bases_list:
    global_pvals_stock[base] = {pair: global_pvals(pair, base=base)
        for pair in combinations(full_angles_list, 2)}
    global_stats_stock[base] = {pair: result.stat for pair, result in global_pvals_stock[base].items()}
    global_pvals_stock[base] = {pair: result.pval for pair, result in global_pvals_stock[base].items()}

for base in bases_list:
    matrix_pvals = pd.DataFrame(index=full_angles_list, columns=full_angles_list, dtype=float)
    matrix_stats = pd.DataFrame(index=full_angles_list, columns=full_angles_list, dtype=float)

    for (X_angle, Y_angle), pval in global_pvals_stock[base].items():
        matrix_pvals.loc[X_angle, Y_angle] = pval
    for (X_angle, Y_angle), stat in global_stats_stock[base].items():
        matrix_stats.loc[X_angle, Y_angle] = stat

    flat_pvals = matrix_pvals.to_numpy().flatten()
    nan_mask_pvals = np.isnan(flat_pvals)
    corrected_pvals = np.full(len(flat_pvals), np.nan)
    corrected_pvals[~nan_mask_pvals] = multipletests(pvals=flat_pvals[~nan_mask_pvals], method='bonferroni')[1]
    non_nan_indices = np.where(~nan_mask_pvals)[0]
    for i in non_nan_indices:
        if corrected_pvals[i] == 0:
            corrected_pvals[i] = 1/NR

    global_pvals_stock[base] = pd.DataFrame(
        corrected_pvals.reshape(matrix_pvals.shape),
        index=matrix_pvals.index,
        columns=matrix_pvals.columns
    )
    global_stats_stock[base] = matrix_stats

# %%
group_colors = {
    "backbone": ("#d81832", slice(0, 6)),
    "base":     ("#4C72B0", slice(6, 7)),
    "sugar":    ("#DD8452", slice(7, 12)),
}

fig, axes = plt.subplots(2, 4, figsize=(30, 15))
axes = axes.flatten()

for i, base in enumerate(bases_list):
    data = global_pvals_stock[base].astype(float)
    data_sym = data.T.where(np.tril(np.ones(data.shape, dtype=bool)))
    mask = np.triu(np.ones(data_sym.shape, dtype=bool), k=1)

    sns.heatmap(
        data_sym,
        ax=axes[i],
        cmap="rocket",
        vmin=0, vmax=1,
        mask=mask
    )
    axes[i].set_title(f"Global p-values - {base}")

    for sep in [6, 7]:
        axes[i].axhline(sep, color="white", linewidth=2, linestyle="--")
        axes[i].axvline(sep, color="white", linewidth=2, linestyle="--")

    for label in axes[i].get_yticklabels():
        j = axes[i].get_yticklabels().index(label)
        for group_name, (color, grp_slice) in group_colors.items():
            if j in range(*grp_slice.indices(12)):
                label.set_bbox(dict(facecolor=color, edgecolor="none", alpha=0.3, pad=3))

    for label in axes[i].get_xticklabels():
        j = axes[i].get_xticklabels().index(label)
        for group_name, (color, grp_slice) in group_colors.items():
            if j in range(*grp_slice.indices(12)):
                label.set_bbox(dict(facecolor=color, edgecolor="none", alpha=0.3, pad=3))

    for group_name, (color, grp_slice) in group_colors.items():
        start = grp_slice.start
        stop = grp_slice.stop
        mid = (start + stop) / 2

        axes[i].text(
            -0.135, mid, group_name,
            transform=axes[i].get_yaxis_transform(),
            fontsize=8, ha="center", va="center",
            color="white", fontweight="bold",
            rotation=90,
            bbox=dict(boxstyle="round,pad=0.4", facecolor=color, edgecolor="none"),
            clip_on=False
        )

        axes[i].text(
            mid, -0.13, group_name,
            transform=axes[i].get_xaxis_transform(),
            fontsize=8, ha="center", va="center",
            color="white", fontweight="bold",
            bbox=dict(boxstyle="round,pad=0.4", facecolor=color, edgecolor="none"),
            clip_on=False
        )

plt.suptitle("Global p-values matrix", size = 18)
plt.tight_layout()
plt.show()

# %%
def solo_base_heatmap(base):

    fig, ax = plt.subplots(figsize=(10, 8))

    data = global_pvals_stock[base].astype(float)
    data_sym = data.T.where(np.tril(np.ones(data.shape, dtype=bool)))
    mask = np.triu(np.ones(data_sym.shape, dtype=bool), k=1)

    sns.heatmap(
        data_sym,
        ax=ax,
        cmap="rocket",
        vmin=0, vmax=1,
        mask=mask
    )
    ax.set_title(f"Global p-values - {base}")

    for sep in [6, 7]:
        ax.axhline(sep, color="white", linewidth=2, linestyle="--")
        ax.axvline(sep, color="white", linewidth=2, linestyle="--")

    for label in ax.get_yticklabels():
        j = ax.get_yticklabels().index(label)
        for group_name, (color, grp_slice) in group_colors.items():
            if j in range(*grp_slice.indices(12)):
                label.set_bbox(dict(facecolor=color, edgecolor="none", alpha=0.3, pad=3))

    for label in ax.get_xticklabels():
        j = ax.get_xticklabels().index(label)
        for group_name, (color, grp_slice) in group_colors.items():
            if j in range(*grp_slice.indices(12)):
                label.set_bbox(dict(facecolor=color, edgecolor="none", alpha=0.3, pad=3))

    for group_name, (color, grp_slice) in group_colors.items():
        start = grp_slice.start
        stop = grp_slice.stop
        mid = (start + stop) / 2

        ax.text(
            -0.1, mid, group_name,
            transform=ax.get_yaxis_transform(),
            fontsize=8, ha="center", va="center",
            color="white", fontweight="bold",
            rotation=90,
            bbox=dict(boxstyle="round,pad=0.4", facecolor=color, edgecolor="none"),
            clip_on=False
        )
        ax.text(
            mid, -0.115, group_name,
            transform=ax.get_xaxis_transform(),
            fontsize=8, ha="center", va="center",
            color="white", fontweight="bold",
            bbox=dict(boxstyle="round,pad=0.4", facecolor=color, edgecolor="none"),
            clip_on=False
        )

    plt.tight_layout()
    plt.show()

# %%
solo_base_heatmap('ACC')

# %%
group_colors = {
    "backbone": ("#d81832", slice(0, 6)),
    "base":     ("#4C72B0", slice(6, 7)),
    "sugar":    ("#DD8452", slice(7, 12)),
}

fig, axes = plt.subplots(2, 4, figsize=(30, 17))
axes = axes.flatten()

cbar_ax = fig.add_axes([0.92, 0.15, 0.02, 0.7])

for i, base in enumerate(bases_list):
    data = global_stats_stock[base].astype(float)
    data_sym = data.T.where(np.tril(np.ones(data.shape, dtype=bool)))
    mask = np.triu(np.ones(data_sym.shape, dtype=bool), k=1)

    data_pvals = global_pvals_stock[base].astype(float)
    data_sym_pvals = data_pvals.T.where(np.tril(np.ones(data_pvals.shape, dtype=bool)))

    sns.heatmap(
        data_sym,
        ax=axes[i],
        cmap="rocket_r",
        mask=mask,
        cbar=i == 0,
        cbar_ax=cbar_ax if i == 0 else None,
        cbar_kws={'label': 'Dependence'})

    for row in range(data_sym_pvals.shape[0]):
        for col in range(data_sym_pvals.shape[1]):
            pval = data_sym_pvals.iloc[row, col]
            if pd.isna(pval):
                continue
            elif pval < 0.05:
                stars = "*"
            else:
                stars = ""
            if stars:
                axes[i].text(
                    col + 0.5, row + 0.5, stars,
                    ha="center", va="center",
                    fontsize=15, color="darkgreen", fontweight="bold"
                )
    
    axes[i].set_title(f"Global mean distances - {base}")

    for sep in [6, 7]:
        axes[i].axhline(sep, color="white", linewidth=2, linestyle="--")
        axes[i].axvline(sep, color="white", linewidth=2, linestyle="--")

    for label in axes[i].get_yticklabels():
        j = axes[i].get_yticklabels().index(label)
        for group_name, (color, grp_slice) in group_colors.items():
            if j in range(*grp_slice.indices(12)):
                label.set_bbox(dict(facecolor=color, edgecolor="none", alpha=0.3, pad=3))

    for label in axes[i].get_xticklabels():
        j = axes[i].get_xticklabels().index(label)
        for group_name, (color, grp_slice) in group_colors.items():
            if j in range(*grp_slice.indices(12)):
                label.set_bbox(dict(facecolor=color, edgecolor="none", alpha=0.3, pad=3))

    for group_name, (color, grp_slice) in group_colors.items():
        start = grp_slice.start
        stop = grp_slice.stop
        mid = (start + stop) / 2

        axes[i].text(
            -0.13, mid, group_name,
            transform=axes[i].get_yaxis_transform(),
            fontsize=9, ha="center", va="center",
            color="white", fontweight="bold",
            rotation=90,
            bbox=dict(boxstyle="round,pad=0.4", facecolor=color, edgecolor="none"),
            clip_on=False
        )

        axes[i].text(
            mid, -0.11, group_name,
            transform=axes[i].get_xaxis_transform(),
            fontsize=9, ha="center", va="center",
            color="white", fontweight="bold",
            bbox=dict(boxstyle="round,pad=0.4", facecolor=color, edgecolor="none"),
            clip_on=False
        )

plt.suptitle("Global statistics matrix", size = 18)
plt.tight_layout(rect=[0, 0, 0.91, 1])
plt.show()

# %%
base = "ACC"
data = global_stats_stock[base].astype(float)
data_sym = data.T.where(np.tril(np.ones(data.shape, dtype=bool)))
mask = np.triu(np.ones(data_sym.shape, dtype=bool), k=1)
data_pvals = global_pvals_stock[base].astype(float)
data_sym_pvals = data_pvals.T.where(np.tril(np.ones(data_pvals.shape, dtype=bool)))

fig, ax = plt.subplots(1, 1, figsize=(8, 7))
cbar_ax = fig.add_axes([0.92, 0.15, 0.02, 0.7])

sns.heatmap(
    data_sym,
    ax=ax,
    cmap="rocket_r",
    mask=mask,
    cbar=True,
    cbar_ax=cbar_ax,
    cbar_kws={'label': 'Dependence'})

for row in range(data_sym_pvals.shape[0]):
    for col in range(data_sym_pvals.shape[1]):
        pval = data_sym_pvals.iloc[row, col]
        if pd.isna(pval):
            continue
        elif pval < 0.05:
            stars = "*"
        else:
            stars = ""
        if stars:
            ax.text(
                col + 0.5, row + 0.5, stars,
                ha="center", va="center",
                fontsize=15, color="darkgreen", fontweight="bold"
            )

ax.set_title(f"Global mean distances - {base}")
for sep in [6, 7]:
    ax.axhline(sep, color="white", linewidth=2, linestyle="--")
    ax.axvline(sep, color="white", linewidth=2, linestyle="--")

for label in ax.get_yticklabels():
    j = ax.get_yticklabels().index(label)
    for group_name, (color, grp_slice) in group_colors.items():
        if j in range(*grp_slice.indices(12)):
            label.set_bbox(dict(facecolor=color, edgecolor="none", alpha=0.3, pad=3))

for label in ax.get_xticklabels():
    j = ax.get_xticklabels().index(label)
    for group_name, (color, grp_slice) in group_colors.items():
        if j in range(*grp_slice.indices(12)):
            label.set_bbox(dict(facecolor=color, edgecolor="none", alpha=0.3, pad=3))

for group_name, (color, grp_slice) in group_colors.items():
    start = grp_slice.start
    stop = grp_slice.stop
    mid = (start + stop) / 2
    ax.text(
        -0.13, mid, group_name,
        transform=ax.get_yaxis_transform(),
        fontsize=9, ha="center", va="center",
        color="white", fontweight="bold",
        rotation=90,
        bbox=dict(boxstyle="round,pad=0.4", facecolor=color, edgecolor="none"),
        clip_on=False
    )
    ax.text(
        mid, -0.11, group_name,
        transform=ax.get_xaxis_transform(),
        fontsize=9, ha="center", va="center",
        color="white", fontweight="bold",
        bbox=dict(boxstyle="round,pad=0.4", facecolor=color, edgecolor="none"),
        clip_on=False
    )

plt.tight_layout(rect=[0, 0, 0.91, 1])
plt.show()

# %% [markdown]
# ### Conformation study

# %%
P_thetas = {}

for base in bases_list :

    P_thetas[base] = mid_angles[base][["nu0", "nu1", "nu2", "nu3", "nu4"]].apply(
        lambda row: P_fun(row), axis=1)

# %%
conformations_clusters = {}

for base in bases_list :
    conformations_clusters[base] = P_thetas[base].apply(get_pucker_conf)

# %%
# merged_data = {
#     base: pd.concat([mid_angles[base], conformations_clusters[base].rename("conformation")], axis=1)
#     for base in bases_list
# }

merged_data = np.load(f'{data_path}merged_angles_conformations', allow_pickle=True).item()

# %%
def calc_and_save_conf(conformation, base, X_angle, Y_angle):
    save_path = f'Conformation_Wasserstein/{conformation}_{base}_{X_angle}_{Y_angle}_distance.npy'
    
    if os.path.exists(save_path):
        print(f"  [SKIP] {conformation} | {base} | {X_angle} vs {Y_angle} déjà calculé")
        return
    
    print(f"  [START] {conformation} | {base} | {X_angle} vs {Y_angle}")
    
    X = mid_angles[base][X_angle].loc[conformations_clusters[base] == conformation]
    Y = mid_angles[base][Y_angle].loc[conformations_clusters[base] == conformation]
    
    results = [w_dist_conditional_y(X, Y, y, bins_side_size=5) for y in y_centers]
    
    data = np.array([
        [r.value, r.pvalue, r.statistic] for r in results
    ])  # shape (72, 3)
    
    np.save(save_path, data)
    print(f"  [DONE] {conformation} | {base} | {X_angle} vs {Y_angle} -> {save_path}")

# %%
# os.makedirs('Conformation_Wasserstein', exist_ok=True)
# y_centers = np.arange(0, 360, 5)

# combos = [
#     (conformation, base, X_angle, Y_angle)
#     for conf in conformations 
#     for base in bases_list
#     for X_angle in full_angles_list
#     for Y_angle in [a for a in full_angles_list if a != X_angle]
# ]

# print(f"Total : {len(combos)} combinaisons ({len(combos) * 72} appels OT)")

# Parallel(n_jobs=-1, backend='threading')(
#     delayed(calc_and_save_conf)(conf, base, X_angle, Y_angle)
#     for conf, base, X_angle, Y_angle in combos
# )

# print("Terminé.")

# %%
def load_results_conf(conformation, base, X_angle):
    other_angles = [a for a in full_angles_list if a != X_angle]
    dfs = {}
    
    for Y_angle in other_angles:
        path = f'/home/onyxia/work//DihedralAnglesStudy/Conformation_Wasserstein/{conformation}_{base}_{X_angle}_{Y_angle}_distance.npy'
        data = np.load(path)
        dfs[Y_angle] = pd.DataFrame(
            data,
            index=y_centers,
            columns=[f'distance_{Y_angle}', f'pvalue_{Y_angle}', f'statistic_{Y_angle}']
        )
    
    return pd.concat(dfs.values(), axis=1)

# %%
# wasserstein_conf = {}
# y_centers = np.arange(0, 360, 5)

# for X_angle in full_angles_list:
#     wasserstein_conf[X_angle] = {}
#     for conf in conformations:
#         wasserstein_conf[X_angle][conf] = {}
#         for base in bases_list:
#             wasserstein_conf[X_angle][conf][base] = load_results_conf(conf, base, X_angle)

# for X_angle in full_angles_list:
#     pvalues_cols = [f"pvalue_{Y_angle}" for Y_angle in full_angles_list if Y_angle != X_angle]
#     adjusted_pvalues_cols = [f"adjusted_pvalue_{Y_angle}" for Y_angle in full_angles_list if Y_angle != X_angle]

#     for conf in conformations:
#         for base in bases_list:
#             df = wasserstein_conf[X_angle][conf][base][pvalues_cols]
#             original_shape = df.shape
#             original_index = df.index

#             pvals_flat = df.to_numpy().flatten()
#             corrected = multipletests(pvals=pvals_flat, method='bonferroni')[1]

#             corrected_df = pd.DataFrame(
#                 corrected.reshape(original_shape),
#                 index=original_index,
#                 columns=adjusted_pvalues_cols
#             )

#             wasserstein_conf[X_angle][conf][base] = pd.concat(
#                 [wasserstein_conf[X_angle][conf][base], corrected_df], axis=1
#             )

# np.save('/home/onyxia/work/Data/full_conformation_Wasserstein_distances', wasserstein_conf)

wasserstein_conf = np.load(f'{data_path}full_conformation_Wasserstein_distances', allow_pickle = True).item()

# %%
def global_pvals_conf(angles, conf, base):
    X_angle, Y_angle = angles

    Y = mid_angles[base][Y_angle].loc[conformations_clusters[base] == conf]
    obj = wasserstein_conf[X_angle][conf][base][f"statistic_{Y_angle}"]

    if len(Y) == 0:
        return SimpleNamespace(pval=np.nan, stat=np.nan)

    bin_counts = pd.Series({
        b: ((Y >= b) & (Y < b + 5)).sum()
        for b in obj.index
    })
    
    mean_stat = (obj*bin_counts).sum()/len(Y)
    out_val = np.mean(sim_free_null >= mean_stat)

    return SimpleNamespace(pval = out_val, stat = mean_stat)

# %%
conf_global_pvals_stock = {}
conf_global_stats_stock = {}

for conf in conformations:
    conf_global_pvals_stock[conf] = {}
    conf_global_stats_stock[conf] = {}

    for base in bases_list:
        results = {pair: global_pvals_conf(pair, conf=conf, base=base)
                    for pair in combinations(full_angles_list, 2)}

        conf_global_stats_stock[conf][base] = {pair: r.stat for pair, r in results.items()}
        conf_global_pvals_stock[conf][base] = {pair: r.pval for pair, r in results.items()}

for conf in conformations:
    for base in bases_list:
        conf_matrix_pvals = pd.DataFrame(index=full_angles_list, columns=full_angles_list, dtype=float)
        conf_matrix_stats = pd.DataFrame(index=full_angles_list, columns=full_angles_list, dtype=float)

        for (X_angle, Y_angle), pval in conf_global_pvals_stock[conf][base].items():
            conf_matrix_pvals.loc[X_angle, Y_angle] = pval
        for (X_angle, Y_angle), stat in conf_global_stats_stock[conf][base].items():
            conf_matrix_stats.loc[X_angle, Y_angle] = stat

        conf_flat_pvals = conf_matrix_pvals.to_numpy().flatten()
        conf_nan_mask_pvals = np.isnan(conf_flat_pvals)
        conf_corrected_pvals = np.full(len(conf_flat_pvals), np.nan)

        if (~conf_nan_mask_pvals).sum() > 0:
            conf_corrected_pvals[~conf_nan_mask_pvals] = multipletests(
                pvals=conf_flat_pvals[~conf_nan_mask_pvals], method='bonferroni'
            )[1]

            conf_non_nan_indices = np.where(~conf_nan_mask_pvals)[0]
            for i in conf_non_nan_indices:
                if conf_corrected_pvals[i] == 0:
                    conf_corrected_pvals[i] = 1 / NR
        else:
            print(f"[SKIP] {conf} | {base} : all p-values are NaN")

        conf_global_pvals_stock[conf][base] = pd.DataFrame(
            conf_corrected_pvals.reshape(conf_matrix_pvals.shape),
            index=conf_matrix_pvals.index,
            columns=conf_matrix_pvals.columns
        )
        conf_global_stats_stock[conf][base] = conf_matrix_stats

# %%
fixed_base = "ACC"
group_colors = {
    "backbone": ("#d81832", slice(0, 6)),
    "base":     ("#4C72B0", slice(6, 7)),
    "sugar":    ("#DD8452", slice(7, 12)),
}

fig, axes = plt.subplots(2, 5, figsize=(30, 15))
axes = axes.flatten()

cbar_ax = fig.add_axes([0.92, 0.15, 0.02, 0.7])

for i, conf in enumerate(conformations):
    data = conf_global_stats_stock[conf][fixed_base].astype(float)
    data_sym = data.T.where(np.tril(np.ones(data.shape, dtype=bool)))
    mask = np.triu(np.ones(data_sym.shape, dtype=bool), k=1)

    data_pvals = conf_global_pvals_stock[conf][fixed_base].astype(float)
    data_sym_pvals = data_pvals.T.where(np.tril(np.ones(data_pvals.shape, dtype=bool)))

    sns.heatmap(
        data_sym,
        ax=axes[i],
        cmap="rocket_r",
        mask=mask,
        cbar=i == 0,
        cbar_ax=cbar_ax if i == 0 else None)

    for row in range(data_sym_pvals.shape[0]):
        for col in range(data_sym_pvals.shape[1]):
            pval = data_sym_pvals.iloc[row, col]
            if pd.isna(pval):
                continue
            elif pval < 0.05:
                stars = "*"
            else:
                stars = ""
            if stars:
                axes[i].text(
                    col + 0.5, row + 0.5, stars,
                    ha="center", va="center",
                    fontsize=20, color="darkgreen", fontweight="bold"
                )
    
    axes[i].set_title(f"Global mean distances - {conf}")

    for sep in [6, 7]:
        axes[i].axhline(sep, color="white", linewidth=2, linestyle="--")
        axes[i].axvline(sep, color="white", linewidth=2, linestyle="--")

    for label in axes[i].get_yticklabels():
        j = axes[i].get_yticklabels().index(label)
        for group_name, (color, grp_slice) in group_colors.items():
            if j in range(*grp_slice.indices(12)):
                label.set_bbox(dict(facecolor=color, edgecolor="none", alpha=0.3, pad=3))

    for label in axes[i].get_xticklabels():
        j = axes[i].get_xticklabels().index(label)
        for group_name, (color, grp_slice) in group_colors.items():
            if j in range(*grp_slice.indices(12)):
                label.set_bbox(dict(facecolor=color, edgecolor="none", alpha=0.3, pad=3))

    for group_name, (color, grp_slice) in group_colors.items():
        start = grp_slice.start
        stop = grp_slice.stop
        mid = (start + stop) / 2

        axes[i].text(
            -0.17, mid, group_name,
            transform=axes[i].get_yaxis_transform(),
            fontsize=10, ha="center", va="center",
            color="white", fontweight="bold",
            rotation=90,
            bbox=dict(boxstyle="round,pad=0.4", facecolor=color, edgecolor="none"),
            clip_on=False
        )

        axes[i].text(
            mid, -0.11, group_name,
            transform=axes[i].get_xaxis_transform(),
            fontsize=10, ha="center", va="center",
            color="white", fontweight="bold",
            bbox=dict(boxstyle="round,pad=0.4", facecolor=color, edgecolor="none"),
            clip_on=False
        )

plt.suptitle(f"Global statistics matrix | {fixed_base}", size = 18)
plt.tight_layout(rect=[0, 0, 0.91, 1])
plt.show()

# %%
def comp_conf_laws(angle_1, angle_2, base, conf_list):

    length = len(conf_list)
    X = mid_angles[base][angle_1]
    Y = mid_angles[base][angle_2]
    
    labels = conformations_clusters[base]
    masked = labels.where(labels.isin(conf_list), other="other")
    df_all = pd.DataFrame({angle_1: X, angle_2: Y, "conformation": masked})

    palette = {conf: sns.color_palette()[i] for i, conf in enumerate(conf_list)}
    palette["other"] = "lightgray"

    
    fig, axes = plt.subplots(length + 1, figsize = (12, 18))

    for ax in axes:
        ax.set_xlim(0, 360)
        ax.set_ylim(0, 360)

    for i, conf in enumerate(conf_list):

        color = palette[conf]
        X_conf = mid_angles[base][angle_1].loc[conformations_clusters[base] == conf]
        Y_conf = mid_angles[base][angle_2].loc[conformations_clusters[base] == conf]
    
        sns.scatterplot(x=X_conf, y=Y_conf, ax=axes[i], alpha=0.5, color=color)
        sns.kdeplot(x=X_conf, y=Y_conf, ax=axes[i], levels=5, color=color)
        axes[i].set_title(f"Conformation: {conf} | {base}")
        axes[i].set_xlabel(angle_1)
        axes[i].set_ylabel(angle_2)

    sns.scatterplot(data=df_all, x=angle_1, y=angle_2, hue="conformation",
                    alpha=0.4, ax=axes[length], palette = palette)
    sns.kdeplot(data=df_all, x=angle_1, y=angle_2, hue="conformation",
                levels=3, ax=axes[length], palette = palette)
    axes[length].set_title(f"All conformations | {base}")

    plt.tight_layout()
    plt.show()

# %%
comp_conf_laws(angle_1 = "delta", angle_2 = "nu3", base = "ACC", conf_list = ["C2' exo", "C4' endo"])

# %%
comp_conf_laws(angle_1 = "delta", angle_2 = "nu3", base = "AAA", conf_list = ["C1' endo", "C4' endo"])

# %%
comp_conf_laws(angle_1 = "chi", angle_2 = "nu1", base = "AAC", conf_list = ["C1' endo", "C4' endo"])

# %%
comp_conf_laws(angle_1 = "alpha", angle_2 = "gamma", base = "AAC", conf_list = ["C1' endo", "C4' endo"])

# %%
comp_conf_laws(angle_1 = "alpha", angle_2 = "gamma", base = "AAA", conf_list = ["C1' endo", "C4' endo"])

# %%
comp_conf_laws(angle_1 = "nu0", angle_2 = "nu4", base = "AAA", conf_list = ["C1' endo", "C4' endo"])

# %% [markdown]
# ### PCA study

# %%
def dvar(Dist_Mat):
    
    Dist_Mat = np.array(Dist_Mat, dtype=float)
    n = Dist_Mat.shape[0]
    np.fill_diagonal(Dist_Mat, 0)

    dim1_mean = Dist_Mat.mean(axis=1)
    dim2_mean = Dist_Mat.mean(axis=0)
    all_mean  = Dist_Mat.mean()

    hat_Mat = (Dist_Mat
               - dim1_mean[:, np.newaxis]
               - dim2_mean[np.newaxis, :]
               + all_mean)

    dvar = np.sum(hat_Mat ** 2) / n ** 2
    return dvar

# %%
cov_mat = {}
Dvar = {}

for base in bases_list:
    
    cov_mat[base] = global_stats_stock[base].combine_first(global_stats_stock[base].T)
    Dvar[base] = dvar(cov_mat[base])
    
    diag = cov_mat[base].to_numpy().copy()
    np.fill_diagonal(diag, Dvar[base])
    
    cov_mat[base] = pd.DataFrame(diag, index=cov_mat[base].index, columns=cov_mat[base].columns)

# %%
cov_mat["CAC"]

# %%
dopython.CovPCA(data = mid_angles["ACA"][full_angles_list] - mid_angles["ACA"][full_angles_list].mean(axis = 0), CovMat = cov_mat["ACA"], values = False)

# %%
CovPCA_fit = {}
for base in bases_list:
    CovPCA_fit[base] = dopython.CovPCA(data = mid_angles[base][full_angles_list] - mid_angles[base][full_angles_list].mean(axis = 0), CovMat = cov_mat[base])

# %%
CovPCA_fit["AAA"]

# %%
def fit_hdbscan(base, mcs, data):
    clusterer = HDBSCAN(min_cluster_size=mcs, metric=tore_dist, copy=True)
    result = clusterer.fit(data)
    print([base, mcs])
    return(base, mcs, result)

# %%
HDBSCAN_fit_all_12angles = {}

results = Parallel(n_jobs=-1, backend='threading')(
    delayed(fit_hdbscan)(base, 50, mid_angles[base][full_angles_list])
    for base in bases_list)

for base, mcs, result in results:
    HDBSCAN_fit_all_12angles.setdefault(base, {})[mcs] = result

# %%
HDBSCAN_fit_all_12angles["AAA"][50].labels_

# %%
fig, axes = plt.subplots(2, 4, figsize = (30, 15))

axes = axes.flatten()
for i, base in enumerate(bases_list):

    labels =  HDBSCAN_fit_all_12angles[base][50].labels_     
    noise_mask = labels == -1
    
    axes[i].scatter(x = CovPCA_fit[base].projection[:,0][noise_mask],
                    y = CovPCA_fit[base].projection[:,1][noise_mask],
                    c = 'lightgrey',
                    alpha = 0.3)

    axes[i].scatter(x = CovPCA_fit[base].projection[:,0][~noise_mask],
                    y = CovPCA_fit[base].projection[:,1][~noise_mask],
                    c = labels[~noise_mask],
                    cmap = 'tab20b')

    axe1_info = CovPCA_fit[base].pct_info[0]
    axe2_info = CovPCA_fit[base].pct_info[1]
    axes[i].set_xlabel(f"1st component | {axe1_info} %")
    axes[i].set_ylabel(f"2nd component | {axe2_info} %")

    axes[i].set_title(f"{base}")

plt.suptitle(r"PCA projections with $\mathbb{T}^{12}$ clusters", size = 20)
