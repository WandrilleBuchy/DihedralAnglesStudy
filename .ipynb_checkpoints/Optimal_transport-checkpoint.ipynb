# %% [markdown]
# # Optimal Transport

# %% [markdown]
# ## Importations and tools functions

# %% [markdown]
# ### Importations

# %%
# %pip install sympy
# %pip install POT
# Out:
# Requirement already satisfied: sympy in /opt/python/lib/python3.13/site-packages (1.14.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/python/lib/python3.13/site-packages (from sympy) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: POT in /opt/python/lib/python3.13/site-packages (0.9.6.post1)
# Requirement already satisfied: numpy>=1.16 in /opt/python/lib/python3.13/site-packages (from POT) (2.4.2)
# Requirement already satisfied: scipy>=1.6 in /opt/python/lib/python3.13/site-packages (from POT) (1.17.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sc
import seaborn as sns
import numpy as np
import ot
import ot.plot
import sklearn.metrics as sme
import matplotlib.pylab as pl

from types import SimpleNamespace
from scipy.stats import vonmises
from warnings import warn
from sympy import Interval, Union

# %%
import sys
sys.path.append('/home/onyxia/work/torus_test_traduction/')

import stat_s1_python
import sim_null_stat_python
import twosample_test_s1_python

# %%
bases_list = ["AAA", "AAC", "CAC", "CAA", "CCC", "CCA", "ACC", "ACA"]

data_path = "/home/onyxia/work/Data/"
torus_trad_path = "/home/onyxia/work/torus_test_traduction/"

# %%
dfs = {}

for base in bases_list:
    dfs[base] = pd.read_csv(f"{data_path}angles_RNA_{base}.csv")

df_all_angles = pd.concat(dfs, axis=1)

# %%
mid_angles = {}
first_angles = {}
last_angles = {}

cols_to_drop = ["res_id", "res_name"]

for base in bases_list:
    
    mid_angles[base] = dfs[base][dfs[base]["res_id"].isin([2])].drop(columns=cols_to_drop)
    first_angles[base] = dfs[base][dfs[base]["res_id"].isin([1])].drop(columns=cols_to_drop)
    last_angles[base] = dfs[base][dfs[base]["res_id"].isin([3])].drop(columns=cols_to_drop)

mid_angles["AAA"]
# Out:
#       chain       alpha        beta       gamma       delta     epsilon  \
# 1         B  305.490140  162.730043   52.603131   78.995842  214.526967
# 4         B  146.988674  193.708737  179.793685   81.382929  225.230787
# 7         B  301.320403  163.375457   50.046480   75.955382  223.673354
# 10        B  295.578929  176.137498   64.087720   81.199826  209.114531
# 13        B  301.868572  168.989858   52.243122   80.262432  210.286872
# ...     ...         ...         ...         ...         ...         ...
# 18052     B  359.243083  115.818572   66.577611   83.483783  186.120445
# 18055     B  143.786438  216.118476  186.337421  148.069144  208.983270
# 18058     B   40.453015  250.096048  248.807834  147.528139  263.262144
# 18061     B  160.606135  190.562729  173.702897   91.886990  229.348767
# 18064     B  144.721439  162.581297   15.843182  147.679407  258.571428
#
#              zeta         nu0         nu1         nu2         nu3         nu4  \
# 1      278.473410    0.070455  336.709644   36.383089  322.671813   23.477230
# 4      283.202503    8.016439  330.418764   38.904281  324.713641   17.215873
# 7      292.092174    4.371440  330.290735   42.360514  319.319860   22.886112
# 10     292.686375  358.939293  337.072121   36.751825  321.620907   24.848753
# 13     280.323108    0.935298  336.664007   35.627748  323.916667   22.172684
# ...           ...         ...         ...         ...         ...         ...
# 18052  256.786693    7.027008  332.352175   36.700126  326.430947   16.744271
# 18055  216.610609  338.920824   36.099064  323.462945   25.241961  357.198641
# 18058   71.416625  339.036145   35.579300  324.210889   24.606173  357.511716
# 18061  292.482836   17.771124  325.291458   37.452448  331.822386    6.719794
# 18064  257.361351  336.093741   38.452847  322.509488   24.639664  359.329837
#
#               eta       theta         chi
# 1      168.948446  209.995984  189.233622
# 4      159.669284  195.684487  179.675616
# 7      163.017130  223.839931  192.378723
# 10     174.891792  219.747934  184.549837
# 13     169.729129  208.902042  193.628678
# ...           ...         ...         ...
# 18052  185.351610  221.568289  297.780053
# 18055  190.847730  170.360477  291.694825
# 18058  230.553841   16.753732   50.805860
# 18061  219.537182  209.696504  185.924817
# 18064   28.475493  323.847736  290.978247
#
# [6022 rows x 15 columns]

# %%
mid_6angles = {}
first_6angles = {}
last_6angles = {}
mid_nu = {}
first_nu = {}
last_nu = {}

for base in bases_list:

    mid_6angles[base] = mid_angles[base][["alpha", "beta", "gamma", "delta", "epsilon", "zeta"]]
    first_6angles[base] = first_angles[base][["alpha", "beta", "gamma", "delta", "epsilon", "zeta"]]
    last_6angles[base] = last_angles[base][["alpha", "beta", "gamma", "delta", "epsilon", "zeta"]]
    
    mid_nu[base] = mid_angles[base][["nu0", "nu1", "nu2", "nu3", "nu4"]]
    first_nu[base] = first_angles[base][["nu0", "nu1", "nu2", "nu3", "nu4"]]
    last_nu[base] = last_angles[base][["nu0", "nu1", "nu2", "nu3", "nu4"]]

# %% [markdown]
# ### Tool functions

# %%
def tore_dist(x, y):
    angle_value = 360.0
    half_val = 180.0
    
    dist_sq = 0.0
    for i in range(len(x)):
        diff = x[i] - y[i]
        short_diff = (diff + half_val) % angle_value - half_val
        dist_sq += short_diff**2
        
    return np.sqrt(dist_sq)

# %%
def tore_dist_sq(x, y):
    return(tore_dist(x,y)**2)

# %%
def quadra_cost(x,y):
    return((x - y)**2)

# %% [markdown]
# ## Distance calculation

# %%
def bins_generator(mean_val, bins):
    
    if (bins > 180): 
        raise ValueError("Bins cannot be bigger than 180°")

    diffMbins = mean_val - bins
    sumMbins = mean_val + bins
    
    if (diffMbins < 0):
        int1 = Interval(0, mean_val)
        int2 = Interval(diffMbins % 360, 360)
        bound_inf = Union(int1, int2)
        bound_sup = Interval(mean_val, sumMbins)
        return(Union(bound_inf, bound_sup))
        
    elif (sumMbins > 360):
        int1 = Interval(0, sumMbins % 360)
        int2 = Interval(mean_val, 360)
        bound_sup = Union(int1, int2)
        bound_inf = Interval(diffMbins, mean_val)
        return(Union(bound_inf, bound_sup))
        
    else :
        return(Interval(diffMbins,sumMbins))

# %%
bins_generator(355,15)
# Out:
# Union(Interval(0, 10), Interval(340, 360))

# %%
in_bins = np.vectorize(lambda x: x in bins_generator(305,5))

# %%
xs = mid_6angles['AAA'][in_bins(mid_6angles['AAA']["beta"])][["alpha"]].to_numpy()
xt = mid_6angles["AAA"][["alpha"]].to_numpy()

# %%
cost_matrix = ot.dist(xs, xt, metric = tore_dist_sq)

# %%
a, b = np.ones(len(xs))/len(xs), np.ones(len(xt))/len(xt)

# %%
test = ot.solve(cost_matrix, a, b)

# %%
test.plan
# Out:
# array([[0.        , 0.        , 0.00016606, ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.00016606, 0.        , ..., 0.        , 0.00016606,
#         0.00016606],
#        [0.00016606, 0.        , 0.        , ..., 0.00016606, 0.        ,
#         0.        ]], shape=(3, 6022))

# %%
np.sqrt(test.value)
# Out:
# np.float64(78.43506202247256)

# %%
dist_nax = np.sqrt(2)*180

# %%
def w_dist(xs, xt, joined_data_1 = False, joined_data_2 = False, mean_val_1 = 180, mean_val_2 = 180, bins_side_size_1 = 5, bins_side_size_2 = 5, p = False, a = 'uniform', b = 'uniform'):
    
    in_bins_1 = np.vectorize(lambda x: x in bins_generator(mean_val_1, bins_side_size_1))
    in_bins_2 = np.vectorize(lambda x: x in bins_generator(mean_val_2, bins_side_size_2))

    xs_masked, xt_masked = xs[in_bins_1].to_numpy(), xt[in_bins_2].to_numpy()

    if not (isinstance(joined_data_1,bool)):  
            xs_masked = xs[in_bins_1(joined_data_1)].to_numpy()

    if not (isinstance(joined_data_2,bool)):  
            xt_masked = xt[in_bins_2(joined_data_2)].to_numpy()

    if (a == 'uniform'):
        a = np.ones(len(xs_masked))/len(xs_masked)

    if (b == 'uniform'):
        b = np.ones(len(xt_masked))/len(xt_masked)

        
    solved = ot.solve_sample(X_a = xs_masked, X_b = xt_masked, a = a, b = b)

    return SimpleNamespace(plan=solved.plan, value=np.sqrt(solved.value))

# %%
testing_fun = w_dist(xs = mid_6angles["AAA"][["alpha"]], xt = mid_6angles["AAA"][["alpha"]], joined_data_1 = mid_6angles['AAA']["beta"], mean_val_1 = 355, bins_side_size_2 = 179)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 testing_fun = w_dist(xs = mid_6angles["AAA"][["alpha"]], xt = mid_6angles["AAA"][["alpha"]], joined_data_1 = mid_6angles['AAA']["beta"], mean_val_1 = 355, bins_side_size_2 = 179)
#
# Cell In[33], line 21, in w_dist(xs, xt, joined_data_1, joined_data_2, mean_val_1, mean_val_2, bins_side_size_1, bins_side_size_2, p, a, b)
#      17 if (b == 'uniform'):
#      18     b = np.ones(len(xt_masked))/len(xt_masked)
# ---> 21 solved = ot.solve_sample(X_a = xs_masked, X_b = xt_masked, a = a, b = b)
#      23 return SimpleNamespace(plan=solved.plan, value=np.sqrt(solved.value))
#
# File /opt/python/lib/python3.13/site-packages/ot/solvers.py:1731, in solve_sample(X_a, X_b, a, b, metric, reg, c, reg_type, unbalanced, unbalanced_type, lazy, batch_size, method, n_threads, max_iter, plan_init, rank, scaling, potentials_init, X_init, tol, verbose, grad, random_state)
#    1727 if not lazy:  # default non lazy solver calls ot.solve
#    1728     # compute cost matrix M and use solve function
#    1729     M = dist(X_a, X_b, metric)
# -> 1731     res = solve(
#    1732         M,
#    1733         a,
#    1734         b,
#    1735         reg,
#    1736         c,
#    1737         reg_type,
#    1738         unbalanced,
#    1739         unbalanced_type,
#    1740         method,
#    1741         n_threads,
#    1742         max_iter,
#    1743         plan_init,
#    1744         potentials_init,
#    1745         tol,
#    1746         verbose,
#    1747         grad,
#    1748     )
#    1750     return res
#    1752 else:
#    1753     # Detect backend
#
# File /opt/python/lib/python3.13/site-packages/ot/solvers.py:323, in solve(M, a, b, reg, c, reg_type, unbalanced, unbalanced_type, method, n_threads, max_iter, plan_init, potentials_init, tol, verbose, grad)
#     320 if max_iter is None:
#     321     max_iter = 1000000
# --> 323 value_linear, log = emd2(
#     324     a,
#     325     b,
#     326     M,
#     327     numItermax=max_iter,
#     328     log=True,
#     329     return_matrix=True,
#     330     numThreads=n_threads,
#     331 )
#     333 value = value_linear
#     334 potentials = (log["u"], log["v"])
#
# File /opt/python/lib/python3.13/site-packages/ot/lp/_network_simplex.py:495, in emd2(a, b, M, processes, numItermax, log, return_matrix, center_dual, numThreads, check_marginals)
#     493 # ensure that same mass
#     494 if check_marginals:
# --> 495     np.testing.assert_almost_equal(
#     496         a.sum(0),
#     497         b.sum(0, keepdims=True),
#     498         err_msg="a and b vector must have the same sum",
#     499         decimal=6,
#     500     )
#     501 b = b * a.sum(0) / b.sum(0, keepdims=True)
#     503 asel = a != 0
#
#     [... skipping hidden 2 frame]
#
# File /opt/python/lib/python3.13/site-packages/numpy/testing/_private/utils.py:983, in assert_array_compare(comparison, x, y, err_msg, verbose, header, precision, equal_nan, equal_inf, strict, names)
#     978         err_msg += '\n' + '\n'.join(remarks)
#     979         msg = build_err_msg([ox, oy], err_msg,
#     980                             verbose=verbose, header=header,
#     981                             names=names,
#     982                             precision=precision)
# --> 983         raise AssertionError(msg)
#     984 except ValueError:
#     985     import traceback
#
# AssertionError:
# Arrays are not almost equal to 6 decimals
# a and b vector must have the same sum
# Mismatched elements: 1 / 1 (100%)
# Mismatch at index:
#  [0]: 0.0 (ACTUAL), 1.0 (DESIRED)
# Max absolute difference among violations: 1.
# Max relative difference among violations: 1.
#  ACTUAL: array(0.)
#  DESIRED: array([1.])

# %%
testing_fun.value

# %%
testing_fun.plan

# %% [markdown]
# ## Tests de corrélation

# %%
NR = 100

try:
    sim_free_null
except NameError:
    sim_free_null = sim_null_stat_python.sim_null_stat(500, NC=2)
# Out:
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
# ...
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:32: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/sim_null_stat_python.py:38: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)

# %%
stock={}
for i in range(1000):
    x, y = np.random.rand(100), np.random.rand(100)
    stock[i] = twosample_test_s1_python.twosample_test_s1(x, y, sim_free_null).pvalue

stock = np.array(list(stock.values()))
# Out:
# /home/onyxia/work/torus_test_traduction/stat_s1_python.py:34: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_alpha, _ = quad(h, 0, 1)
# /home/onyxia/work/torus_test_traduction/stat_s1_python.py:40: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   optimal_h_alpha, _ = quad(h_alpha, 0, 1)
# /home/onyxia/work/torus_test_traduction/stat_s1_python.py:34: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   optimal_alpha, _ = quad(h, 0, 1)

# %%
plt.hist(stock, edgecolor = 'black')
plt.title(r"pvalues of the 1000 two 100-samples tests on $\mathbb{S}^1$")
# Out:
# Text(0.5, 1.0, 'pvalues of the 1000 two 100-samples tests on $\\mathbb{S}^1$')
